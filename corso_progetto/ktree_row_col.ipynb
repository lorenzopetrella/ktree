# %% [markdown]
# # **Set according to environment (e.g. local, Google Colab...)**

# %%
project_folder = ''

# %% [markdown]
# # **Body**

# %%
from custom_libraries.miscellaneous import *
from custom_libraries.image_dataset import *
from custom_libraries.ktree import *
import numpy as np

# %%
import gc

# Initialize settings
bs = 256
trials = 10
epochs = 2000
trees_set = [1]

# Load class-dataset list
# classes = np.load(project_folder + 'results/classes.npy', allow_pickle=True)

classes = [[3, 5, 'mnist'],
           [0, 6, 'fmnist'],
           [14, 17, 'emnist'],
           [2, 6, 'kmnist'],
           [3, 5, 'cifar10'],
           [5, 6, 'svhn'],
           [3, 5, 'usps']]

callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_binary_crossentropy', patience=2000),
             tf.keras.callbacks.ModelCheckpoint(filepath="checkpoints/ktree_orig_checkpoint",
                                                monitor='val_binary_crossentropy',
                                                verbose=0,
                                                save_best_only=True,
                                                save_weights_only=True,
                                                )]

history = np.load(project_folder + 'results/ktree_history.npy', allow_pickle=True)
#history = np.zeros((len(classes), trials, len(trees_set), 2))


for j, (t1, t2, ds) in enumerate(classes):

    # escludo i dataset a colori per il momento
    if ds in ['cifar10', 'svhn']:
        continue

    print(f"Dataset: {ds} / Pair: {t1}-{t2}")

    test_ds = ImageDataset(ds, 'test', data_dir=None, shuffle_files=False)
    train_ds = ImageDataset(ds, 'train', data_dir=None, shuffle_files=False)
    test_ds_2 = ImageDataset(ds, 'test', data_dir=None, shuffle_files=False)
    train_ds_2 = ImageDataset(ds, 'train', data_dir=None, shuffle_files=False)

    for x in [train_ds, test_ds, train_ds_2, test_ds_2]:
        x.filter(t1, t2, overwrite=True)
        x.normalize()
        if x.images.shape[1:3] == (28, 28):
            x.pad()

    for x in [train_ds, test_ds]:
        x.vectorize(merge_channels=True, by_row=True)

    for x in [train_ds_2, test_ds_2]:
        x.vectorize(merge_channels=True, by_row=False)

    for (x, y) in [(train_ds, train_ds_2), (test_ds, test_ds_2)]:
        x.images = np.concatenate((x.images, y.images), axis=1)
        x.labels = np.concatenate((x.labels, y.labels), axis=None)
        x.shuffle()

    del train_ds_2, test_ds_2

    for k, trees in enumerate(trees_set):

        print(f"{trees}-tree")

        test_set = tf.data.Dataset.from_tensor_slices((test_ds.images, test_ds.labels)).map(
            lambda x, y: (tf.tile(x, [trees]), y)).batch(bs)

        for i in range(trials):

            #if history[j, i, k, 0] != 0:
            #    continue

            print(f"Trial {i + 1}")

            with tf.device('/device:GPU:0'):

                X_train, y_train, X_valid, y_valid = train_ds.bootstrap(.85, True)

                model = create_model(input_size=X_train.shape[1] * trees, num_trees=trees, use_bias=True)

                train_set = tf.data.Dataset.from_tensor_slices((X_train, y_train)).map(
                    lambda x, y: (tf.tile(x, [trees]), y)).batch(bs)
                valid_set = tf.data.Dataset.from_tensor_slices((X_valid, y_valid)).map(
                    lambda x, y: (tf.tile(x, [trees]), y)).batch(bs)

                fit_history = model.fit(x=train_set, batch_size=bs, epochs=epochs,
                                        validation_data=valid_set, validation_batch_size=bs,
                                        callbacks=callbacks, verbose=1)
                print_fit_history(fit_history, epochs)
                model.load_weights('checkpoints/ktree_orig_checkpoint')

                evaluate_history = model.evaluate(x=test_set, batch_size=bs, verbose=0)
                print_evaluate_history(evaluate_history)

                history[j, i, k] = evaluate_history[1:]

                np.save(project_folder + 'results/ktree_history.npy', history,
                        allow_pickle=True)

                del model, train_set, valid_set, X_train, y_train, X_valid, y_valid
                gc.collect()
# Out:
# Dataset: mnist / Pair: 3-5
# 1-tree
# Trial 1
# Epoch 1/2000
# 39/39 [==============================] - 2s 27ms/step - loss: 0.6911 - binary_crossentropy: 0.6911 - acc: 0.5266 - val_loss: 0.6883 - val_binary_crossentropy: 0.6883 - val_acc: 0.5401
# Epoch 2/2000
# 39/39 [==============================] - 1s 22ms/step - loss: 0.6877 - binary_crossentropy: 0.6877 - acc: 0.5291 - val_loss: 0.6833 - val_binary_crossentropy: 0.6833 - val_acc: 0.5401
# Epoch 3/2000
# 39/39 [==============================] - 1s 22ms/step - loss: 0.6802 - binary_crossentropy: 0.6802 - acc: 0.5291 - val_loss: 0.6723 - val_binary_crossentropy: 0.6723 - val_acc: 0.5401
# Epoch 4/2000
# 39/39 [==============================] - 1s 20ms/step - loss: 0.6660 - binary_crossentropy: 0.6660 - acc: 0.5291 - val_loss: 0.6531 - val_binary_crossentropy: 0.6531 - val_acc: 0.5401
# Epoch 5/2000
# 39/39 [==============================] - 1s 25ms/step - loss: 0.6441 - binary_crossentropy: 0.6441 - acc: 0.5976 - val_loss: 0.6266 - val_binary_crossentropy: 0.6266 - val_acc: 0.5967
# Epoch 6/2000
# 39/39 [==============================] - 1s 23ms/step - loss: 0.6153 - binary_crossentropy: 0.6153 - acc: 0.6804 - val_loss: 0.5938 - val_binary_crossentropy: 0.5938 - val_acc: 0.6947
# Epoch 7/2000
# 39/39 [==============================] - 1s 23ms/step - loss: 0.5806 - binary_crossentropy: 0.5806 - acc: 0.7446 - val_loss: 0.5570 - val_binary_crossentropy: 0.5570 - val_acc: 0.7415
# Epoch 8/2000
# 39/39 [==============================] - 1s 19ms/step - loss: 0.5416 - binary_crossentropy: 0.5416 - acc: 0.8092 - val_loss: 0.5197 - val_binary_crossentropy: 0.5197 - val_acc: 0.8102
# Epoch 9/2000
# 39/39 [==============================] - 1s 23ms/step - loss: 0.5069 - binary_crossentropy: 0.5069 - acc: 0.8338 - val_loss: 0.4905 - val_binary_crossentropy: 0.4905 - val_acc: 0.8304
# Epoch 10/2000
# 39/39 [==============================] - 1s 22ms/step - loss: 0.4810 - binary_crossentropy: 0.4810 - acc: 0.8476 - val_loss: 0.4688 - val_binary_crossentropy: 0.4688 - val_acc: 0.8402
# Epoch 11/2000
# 39/39 [==============================] - 1s 22ms/step - loss: 0.4614 - binary_crossentropy: 0.4614 - acc: 0.8577 - val_loss: 0.4516 - val_binary_crossentropy: 0.4516 - val_acc: 0.8534
# Epoch 12/2000
# 39/39 [==============================] - 1s 21ms/step - loss: 0.4441 - binary_crossentropy: 0.4441 - acc: 0.8659 - val_loss: 0.4351 - val_binary_crossentropy: 0.4351 - val_acc: 0.8604
# Epoch 13/2000
# 39/39 [==============================] - 1s 21ms/step - loss: 0.4291 - binary_crossentropy: 0.4291 - acc: 0.8710 - val_loss: 0.4211 - val_binary_crossentropy: 0.4211 - val_acc: 0.8679
# Epoch 14/2000
# 39/39 [==============================] - 1s 21ms/step - loss: 0.4147 - binary_crossentropy: 0.4147 - acc: 0.8750 - val_loss: 0.4076 - val_binary_crossentropy: 0.4076 - val_acc: 0.8742
# Epoch 15/2000
# 39/39 [==============================] - 1s 19ms/step - loss: 0.4011 - binary_crossentropy: 0.4011 - acc: 0.8808 - val_loss: 0.3957 - val_binary_crossentropy: 0.3957 - val_acc: 0.8782
# Epoch 16/2000
# 39/39 [==============================] - 1s 20ms/step - loss: 0.3884 - binary_crossentropy: 0.3884 - acc: 0.8848 - val_loss: 0.3826 - val_binary_crossentropy: 0.3826 - val_acc: 0.8817
# Epoch 17/2000
# 32/39 [=======================>......] - ETA: 0s - loss: 0.3791 - binary_crossentropy: 0.3791 - acc: 0.8885
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 32>()
#      71 train_set = tf.data.Dataset.from_tensor_slices((X_train, y_train)).map(
#      72     lambda x, y: (tf.tile(x, [trees]), y)).batch(bs)
#      73 valid_set = tf.data.Dataset.from_tensor_slices((X_valid, y_valid)).map(
#      74     lambda x, y: (tf.tile(x, [trees]), y)).batch(bs)
# ---> 76 fit_history = model.fit(x=train_set, batch_size=bs, epochs=epochs,
#      77                         validation_data=valid_set, validation_batch_size=bs,
#      78                         callbacks=callbacks, verbose=1)
#      79 print_fit_history(fit_history, epochs)
#      80 model.load_weights('checkpoints/ktree_orig_checkpoint')
#
# File c:\pythonvenv\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\pythonvenv\lib\site-packages\keras\engine\training.py:1435, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1432   val_logs = {'val_' + name: val for name, val in val_logs.items()}
#    1433   epoch_logs.update(val_logs)
# -> 1435 callbacks.on_epoch_end(epoch, epoch_logs)
#    1436 training_logs = epoch_logs
#    1437 if self.stop_training:
#
# File c:\pythonvenv\lib\site-packages\keras\callbacks.py:416, in CallbackList.on_epoch_end(self, epoch, logs)
#     414 logs = self._process_logs(logs)
#     415 for callback in self.callbacks:
# --> 416   callback.on_epoch_end(epoch, logs)
#
# File c:\pythonvenv\lib\site-packages\keras\callbacks.py:1388, in ModelCheckpoint.on_epoch_end(self, epoch, logs)
#    1386 # pylint: disable=protected-access
#    1387 if self.save_freq == 'epoch':
# -> 1388   self._save_model(epoch=epoch, batch=None, logs=logs)
#
# File c:\pythonvenv\lib\site-packages\keras\callbacks.py:1440, in ModelCheckpoint._save_model(self, epoch, batch, logs)
#    1438 self.best = current
#    1439 if self.save_weights_only:
# -> 1440   self.model.save_weights(
#    1441       filepath, overwrite=True, options=self._options)
#    1442 else:
#    1443   self.model.save(filepath, overwrite=True, options=self._options)
#
# File c:\pythonvenv\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\pythonvenv\lib\site-packages\keras\engine\training.py:2497, in Model.save_weights(self, filepath, overwrite, save_format, options)
#    2495 else:
#    2496   session = backend.get_session()
# -> 2497 self._trackable_saver.save(filepath, session=session, options=options)
#    2498 # Record this checkpoint so it's visible from tf.train.latest_checkpoint.
#    2499 tf.__internal__.train.update_checkpoint_state(
#    2500     save_dir=os.path.dirname(filepath),
#    2501     model_checkpoint_path=filepath,
#    2502     save_relative_paths=True,
#    2503     all_model_checkpoint_paths=[filepath])
#
# File c:\pythonvenv\lib\site-packages\tensorflow\python\training\tracking\util.py:1262, in TrackableSaver.save(self, file_prefix, checkpoint_number, session, options)
#    1259 if not tensor_util.is_tensor(file_prefix):
#    1260   file_io.recursive_create_dir(os.path.dirname(file_prefix))
# -> 1262 save_path, new_feed_additions = self._save_cached_when_graph_building(
#    1263     file_prefix_tensor, object_graph_tensor, options)
#    1264 if new_feed_additions:
#    1265   feed_dict.update(new_feed_additions)
#
# File c:\pythonvenv\lib\site-packages\tensorflow\python\training\tracking\util.py:1206, in TrackableSaver._save_cached_when_graph_building(self, file_prefix, object_graph_tensor, options)
#    1198 if (self._last_save_object_graph != graph_proto
#    1199     # When executing eagerly, we need to re-create SaveableObjects each time
#    1200     # save() is called so they pick up new Tensors passed to their
#    1201     # constructors. That means the Saver needs to be copied with a new
#    1202     # var_list.
#    1203     or context.executing_eagerly() or ops.inside_function()):
#    1204   saver = functional_saver.MultiDeviceSaver(named_saveable_objects,
#    1205                                             registered_savers)
# -> 1206   save_op = saver.save(file_prefix, options=options)
#    1207   with ops.device("/cpu:0"):
#    1208     with ops.control_dependencies([save_op]):
#
# File c:\pythonvenv\lib\site-packages\tensorflow\python\training\saving\functional_saver.py:371, in MultiDeviceSaver.save(self, file_prefix, options)
#     369   tf_function_save()
#     370 else:
# --> 371   return save_fn()
#
# File c:\pythonvenv\lib\site-packages\tensorflow\python\training\saving\functional_saver.py:357, in MultiDeviceSaver.save.<locals>.save_fn()
#     350 merge_device = (
#     351     options.experimental_io_device or
#     352     saveable_object_util.set_cpu0(last_device))
#     353 with ops.device(merge_device):
#     354   # V2 format write path consists of a metadata merge step.  Once
#     355   # merged, attempts to delete the temporary directory,
#     356   # "<user-fed prefix>_temp".
# --> 357   return gen_io_ops.merge_v2_checkpoints(
#     358       saved_prefixes, file_prefix, delete_old_dirs=True)
#
# File c:\pythonvenv\lib\site-packages\tensorflow\python\ops\gen_io_ops.py:512, in merge_v2_checkpoints(checkpoint_prefixes, destination_prefix, delete_old_dirs, name)
#     510   pass
#     511 try:
# --> 512   return merge_v2_checkpoints_eager_fallback(
#     513       checkpoint_prefixes, destination_prefix,
#     514       delete_old_dirs=delete_old_dirs, name=name, ctx=_ctx)
#     515 except _core._SymbolicException:
#     516   pass  # Add nodes to the TensorFlow graph.
#
# File c:\pythonvenv\lib\site-packages\tensorflow\python\ops\gen_io_ops.py:537, in merge_v2_checkpoints_eager_fallback(checkpoint_prefixes, destination_prefix, delete_old_dirs, name, ctx)
#     535 _inputs_flat = [checkpoint_prefixes, destination_prefix]
#     536 _attrs = ("delete_old_dirs", delete_old_dirs)
# --> 537 _result = _execute.execute(b"MergeV2Checkpoints", 0, inputs=_inputs_flat,
#     538                            attrs=_attrs, ctx=ctx, name=name)
#     539 _result = None
#     540 return _result
#
# File c:\pythonvenv\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
history = np.load(project_folder + 'results/ktree_history.npy', allow_pickle=True)
print("RESULTS:")
for j, (t1, t2, ds) in enumerate(classes):
    print(f"Dataset: {ds} / Pair: {t1}-{t2}")
    for k, trees in enumerate(trees_set):
        print(f"{trees}-tree")
        print(f"Accuracy: {round(np.mean(history[j, :, k, 1]), 4)} ± {round(np.std(history[j, :, k, 1]), 4)}")
